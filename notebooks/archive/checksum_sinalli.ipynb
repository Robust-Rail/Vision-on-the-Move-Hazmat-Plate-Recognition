# %%
import hashlib
import csv
import os
import imagehash
from PIL import Image
def file_checksum(filepath, algo="sha256"):
    """Calculate the checksum of a file."""
    h = hashlib.new(algo)
    with open(filepath, "rb") as f:
        for chunk in iter(lambda: f.read(4096), b""):
            h.update(chunk)
    return h.hexdigest()
def image_visual_hash(image_path):
    try:
        return str(imagehash.average_hash(Image.open(image_path)))
    except Exception as e:
        print(f"Error hashing {image_path}: {e}")
        return None
def extend_csv_with_checksum(csv_path, output_csv, filename_column="filename", base_dir="."):
    """Extend an existing CSV with a checksum column."""
    with open(csv_path, newline="", encoding="utf-8") as infile:
        reader = csv.DictReader(infile)
        rows = list(reader)
        fieldnames = reader.fieldnames + ["checksum", "visual_hash"]

    for row in rows:
        filename = row[filename_column]
        file_path = os.path.join(base_dir, filename + ".jpg")  # Assuming files are .jpg, adjust as necessary
        if os.path.isfile(file_path):
            checksum = file_checksum(file_path)
            image_hash = image_visual_hash(file_path)
        else:
            file_path = os.path.join(base_dir, filename + ".png") 
            if os.path.isfile(file_path):
                checksum = file_checksum(file_path)
                image_hash = image_visual_hash(file_path)
            else:
                checksum = "File not found"
                image_hash = "File not found"
        row["checksum"] = checksum
        row["visual_hash"] = image_hash

    with open(output_csv, "w", newline="", encoding="utf-8") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

# Example usage:
# create_checksums_from_csv("filenames.csv", "checksums.csv", base_dir="./data")

# %%
extend_csv_with_checksum("../../data/public_dataset.csv", "../../data/public_dataset_with_checksum_image.csv", "Image_id",base_dir=r"C:\Users\stani\.cache\kagglehub\datasets\stanislavlevendeev\haz-mat-signs\versions\7\images")

# %%
import requests
from bs4 import BeautifulSoup
import csv
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

def get_image_urls(url):
    resp = requests.get(url)
    soup = BeautifulSoup(resp.content, "html.parser")
    img_tags = soup.find_all("img")
    img_urls = []
    for img in img_tags:
        src = img.get("src")
        if src:
            # check if contains a thumb in the link
            if src.startswith("http") and "thumb" in src:
                img_urls.append(src.replace("thumb", "original"))
            else:
                next()
                img_urls.append(requests.compat.urljoin("https://www.sinanlitanker.com.tr/", src))
    return img_urls
def get_image_urls_dynamic(url, wait_time=10):
    options = Options()
    options.add_argument("--headless")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
    time.sleep(wait_time)  # Wait for JS to load content; adjust as needed

    img_elements = driver.find_elements(By.TAG_NAME, "img")
    img_urls = []
    for img in img_elements:
        src = img.get_attribute("src")
        if src:
            if src.startswith("http") and "thumb" in src:
                img_urls.append(src.replace("thumb", "original"))
    driver.quit()
    return img_urls
counter = 0
def download_image(url, dest_folder="../../data/downloaded_images"):
    os.makedirs(dest_folder, exist_ok=True)
    resp = requests.get(url, stream=True)
    global counter
    counter += 1
    filename = os.path.join(dest_folder, str(counter)+os.path.basename(url.split("?")[0]))
    if resp.status_code == 200:
        with open(filename, "wb") as f:
            for chunk in resp.iter_content(1024):
                f.write(chunk)
        return filename
    return None

def image_visual_hash(image_path):
    try:
        return str(imagehash.average_hash(Image.open(image_path)))
    except Exception as e:
        print(f"Error hashing {image_path}: {e}")
        return None

def update_csv_links_with_direct_images(page_url, csv_path, output_csv, checksum_column="checksum", link_column="link", use_visual_hash=True):
    # 1. Scrape and download images, compute checksums and visual hashes
    img_urls = get_image_urls_dynamic(page_url)
    checksum_to_url = {}
    visualhash_to_url = {}
    for img_url in img_urls:
        print(f"Processing: {img_url}")
        local_path = download_image(img_url)
        if local_path:
            checksum = file_checksum(local_path)
            checksum_to_url[checksum] = img_url
            if use_visual_hash:
                vhash = image_visual_hash(local_path)
                if vhash:
                    visualhash_to_url[vhash] = img_url

    # 2. Read the original CSV and update links if checksum or visual hash matches
    with open(csv_path, newline="", encoding="utf-8") as infile:
        reader = csv.DictReader(infile)
        rows = list(reader)
        fieldnames = reader.fieldnames

    for row in rows:
        checksum = row.get(checksum_column)
        updated = False
        # Try file checksum match first
        if checksum in checksum_to_url:
            row[link_column] = checksum_to_url[checksum]
            updated = True
        # If not found, try visual hash match
        elif use_visual_hash:
            # Compute visual hash for local file
            filename = row.get("filename") or row.get("Image_id") or row.get("image_name")
            if filename:
                # Try .jpg and .png
                for ext in [".jpg", ".png"]:
                    local_file = os.path.join(r"C:\Users\stani\.cache\kagglehub\datasets\stanislavlevendeev\haz-mat-signs\versions\7\images", filename + ext)
                    if os.path.isfile(local_file):
                        vhash = image_visual_hash(local_file)
                        if vhash and vhash in visualhash_to_url:
                            row[link_column] = visualhash_to_url[vhash]
                            updated = True
                            break
            if not updated:
                row[link_column] = row.get(link_column, "")

    # 3. Write updated CSV
    with open(output_csv, "w", newline="", encoding="utf-8") as outfile:
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

# %%
# Example usage:
update_csv_links_with_direct_images(
    page_url="https://universe.roboflow.com/masters-thesis-yolo-model/adr-tankers-detection/browse?queryText=&pageSize=200&startingIndex=0&browseQuery=true",
    csv_path="../../data/public_dataset_with_checksum_image_updated.csv",
    output_csv="../../data/public_dataset_with_checksum_image_updated_2.csv",
    checksum_column="checksum",
    link_column="Link"
)
# Out:
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/OMoG5MiCkD1bz8uQMrnp/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/qAHNGmcYp0m5ezvxcPQH/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/08qq4lFVxmJQZ6hCVQD5/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/eNI1H2fEPbbBGOXIiloc/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/zTmAIyMHfbthnlCLaZW4/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Zb55M2bOHl4PJvMc1Po6/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/UXdTQWbpFW64mCH9UiTX/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Wsq4bG2JIUsEXlVoMooe/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/rNgCMy0iMoVGTfe4r476/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/ulwkTKFF3vgmCzLfaXR4/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/lanSXXrBwssCLsOBbc04/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/R1G9lt44JpamkwtL4EGS/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/ZF3Lkav8xCEAxlTMbJOb/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/PVgNyBENg7Jf30ZON8ZR/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/mNwXIlONULvpNbU23Hvk/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/BGn1JmQz0hgCNUE73cZu/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/PBUbVsQOIKc7g6S7QRw4/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/TwtIBKUQSy2ugUdE6CNB/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/87sxGQ8PEy7gj4aoKEBC/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/NPejKZ41aLkTWI2pWGNX/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/vt4lU1qARm1Al0wm9ooz/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/hG4e7xOnwFrOQVnJYAOA/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/I4kuH2jnVgQTauy54jaI/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/rZPUBswrvLXU2b1HpEK5/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/hgJ7aAxryy60ljrJ4FRP/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/LuCzLxFjhq5n01edZl6D/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/LoKgSKAEBzEIPPN0zVl3/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/dBt4JrwwHMtbXuNb5vmY/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/stt3RhkXb2sRpG6NqNe3/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/LxoAE3vnL5fw6BGdZES5/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/H23wbEvpoVyAahprJ9d1/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/U2m3akL8Lr8ipZ7B9xFJ/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/6RUFhlZA2fUVwup89qNx/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/7N2xNHbyrHPfhu8SxJLS/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/YDj9ibp4mB2hDhfriCjc/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/cm8geR7fl1u4QmvUswZm/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/UFyhtKw3i30QrjrBJAB5/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/3xSV3TLbWPIp9LRhwBwr/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/scKWjDtSeVMOnD2mvRTW/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/PWjUk6flTa2MVSEuGPqQ/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/me2xJuiy4hollmvO48if/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/YvzLOG5QhUXQIzrDm0XA/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Dk0P1f8X37NUzXFb2SAa/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/nNsKoxOE35XE4Xf9s6MZ/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/dzOGKjiUWCioHiaEAd4v/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/4b0Z0Or0OpWye723U0OU/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/IsKbTV1wEJI2VtaHsp2j/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/SnTFAqC9rJNQtr2AmI8x/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/4NDvOhVeIV9Xi5UKCP5N/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/9cIi592QTdrKeau0DpTP/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/J7nRML2gRn3YYzx9o8p5/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/aZ5kXTuxlRuTw44ds5Ut/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/bVf3PUAz2XbUD2Di500i/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/BEpLh2YkUpGK21R7BPdC/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/BUqnVF7MjuXm5RDc1xUT/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/LlyDvXAKzxiKc6CQu8lX/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/xn4NfdfJ0mbrBtrHp43O/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/SsBidji55m6vP0nw7wHw/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/5USBeCw4a2flhSU7Q4hB/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Yc0vHQIGP3POogctWWNr/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/vcAFqIu5cQCPqlmeiOv1/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/wGY6ORUM4f3q8EPrtPUa/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Kvjtq0SMfbzEdYLD4kuZ/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/GjCYCSAqmjsiuYt6ckph/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/jBoyJITMWP8koOLqAp7E/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/vshME0kAFcDkpMDoI1dI/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Hd8j3kCsuNB4LxaEIjdW/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/dmwPLbZiIyJ6eI1hE1ic/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/LR0p5cqXiAU83fXCcIlg/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/5lonoipy0FrbL2yWpM99/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Ob05YSWpj69dfFpEzGZ7/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/o4oSJzN8me1MM4Nu3TQ9/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/sK7ADAlycXJ70vi6NG8r/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/ExqDEDJB2E8rx5mVz6jg/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/PvUx8LLhqjeEZYFKczpj/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/lLG213MCEhzXEF6ThG3g/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/NUD9pBkrupxKOYl81qGl/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/X9raw7oq1CYdWEWT9k8h/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/iCYmYHjUQWPmMPmrKsrk/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/uwXTCJRWWzwK0mrSp7z1/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/NSDzhigddxTTXD1p6THN/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Q2MHusyFUBZMkRtq38xR/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/ld3IlumoNQtJrEmRLkZB/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/wJn6LrhbnHGxkOaAL2cL/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/TkvWnjuVccZFy4mKLlvx/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/RopScNQEHrBq06B7Byuk/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/BNPOGmsckioFrVcsENQJ/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/ZOuKkEEjw31gKIHHmF8O/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/lygduixgbpaWAW16bXa0/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/3k19lS1nbNiWrhahAI74/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Z7O3bu709OZFOs0OKy12/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/yf1QmWgEtyxWlI5MPjJN/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/hhlcUXb0Lp3LM3LcpDm9/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/WkMnkcVZyysUB0to4zQZ/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/tWO5Kc1k9oUXiIC80aj7/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/VAantyoe2QfWR2AWky7f/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Oc5D4njsCToFZLrBVvZH/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/KNjydWZd3RAVFy8yOsKu/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/dDxm9PFLCaMUe0vPWXkR/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/epaGfbKzV4z5D0twgw7W/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/SGOgp2Nc64vTN9YV3tPd/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/c7HydoGj9TnQAqZqAlfN/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/ct7JLTf5nzOC6t2C7dpn/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/kKzh662gi1FbF5qa4q0r/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/mWG7SIEFyCDp0s0lRB3p/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/MEWNQoq1lPPbi0t64vV1/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/FdHgRvsCVo6Fn452k8QV/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/5ynEmV3lpcR3itUK2gLN/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/THqm7GYe3wZ3dLSQdxoD/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/9trLkvoYXuf2K4uQNyEZ/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/VR6RPvAK1EtPBN2fKbph/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/3IyXhr9lS6fLsuYEyfvy/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/3YD93nszQD9ZTaSH2tA9/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/FHRecH5Uj5wa0a0DNkHt/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/z1uSKgSX9h1KipvDOCJM/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/STrWrbMeTvLwzPw1XRBu/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/0L3c0NkVxzwa3sTyf2Js/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/8gHL6BCGibf8Lhq0hgwH/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/JGfNOmIqHnSYJjmPrqo4/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/a0e5wQFxJrSbga19iXE3/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/408gDAy4QSWQzD4EyrN4/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/MykVIyu4YMSeR6e2IYjU/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/Wl97xCMhKUbKqasGpo6D/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/LPlS21MmxtsB7iX6xq6q/original.jpg
# Processing: https://source.roboflow.com/XZtYbRZ7qB4ilZN5GngD/arxrzbUB5m6AnVY37Qin/original.jpg
